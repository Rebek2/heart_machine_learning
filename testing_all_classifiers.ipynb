# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
import pandas as pd
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import classification_report, confusion_matrix
df = pd.read_csv("heart_disease_health_indicators_BRFSS2015.csv")

# %%
clas = [
    LinearSVC(class_weight = 'balanced',random_state = 0),
    KNeighborsClassifier(),
    SVC(kernel ='poly' ,class_weight = 'balanced',random_state = 0),
    SVC(kernel ='linear' ,class_weight = 'balanced',random_state = 0),
    SVC(kernel ='sigmoid' ,class_weight = 'balanced',random_state = 0),
    DecisionTreeClassifier(class_weight = 'balanced',random_state = 0),
    RandomForestClassifier(class_weight = 'balanced',random_state = 0),
    AdaBoostClassifier(random_state = 0),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
    GradientBoostingClassifier(loss = 'deviance',random_state = 0),
    GradientBoostingClassifier(loss = 'exponential',random_state = 0),
]

#kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} or callable, default=’rbf’
#loss{‘log_loss’, ‘deviance’, ‘exponential’}, default=’log_loss’ GBC

# %%
X=df.drop('HeartDiseaseorAttack',axis=1)
y = df['HeartDiseaseorAttack']
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle = True,
                                                     stratify=y,random_state=0)

klasyf = 0
for i in clas:
    klasyf = i
    klasyf.fit(X_train,y_train)
    y_pred = klasyf.predict(X_test)
    print('{}:'.format(i))
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))#print zrobic
    print('------------------------------------------')
    print('------------------------------------------')
# Out:
# /Users/adam/opt/miniconda3/envs/vivenv/lib/python3.8/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(class_weight='balanced', random_state=0):
# [[57001   446]
#  [ 5481   492]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95     57447
#          1.0       0.52      0.08      0.14      5973
#
#     accuracy                           0.91     63420
#    macro avg       0.72      0.54      0.55     63420
# weighted avg       0.88      0.91      0.87     63420
#
# ------------------------------------------
# ------------------------------------------
# KNeighborsClassifier():
# [[56177  1270]
#  [ 5325   648]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.98      0.94     57447
#          1.0       0.34      0.11      0.16      5973
#
#     accuracy                           0.90     63420
#    macro avg       0.63      0.54      0.55     63420
# weighted avg       0.86      0.90      0.87     63420
#
# ------------------------------------------
# ------------------------------------------
# SVC(class_weight='balanced', kernel='poly', random_state=0):
# [[42027 15420]
#  [ 1159  4814]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.84     57447
#          1.0       0.24      0.81      0.37      5973
#
#     accuracy                           0.74     63420
#    macro avg       0.61      0.77      0.60     63420
# weighted avg       0.90      0.74      0.79     63420
#
# ------------------------------------------
# ------------------------------------------
# SVC(class_weight='balanced', kernel='linear', random_state=0):
# [[41850 15597]
#  [ 1118  4855]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.73      0.83     57447
#          1.0       0.24      0.81      0.37      5973
#
#     accuracy                           0.74     63420
#    macro avg       0.61      0.77      0.60     63420
# weighted avg       0.90      0.74      0.79     63420
#
# ------------------------------------------
# ------------------------------------------
# SVC(class_weight='balanced', kernel='sigmoid', random_state=0):
# [[27071 30376]
#  [ 3101  2872]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.47      0.62     57447
#          1.0       0.09      0.48      0.15      5973
#
#     accuracy                           0.47     63420
#    macro avg       0.49      0.48      0.38     63420
# weighted avg       0.82      0.47      0.57     63420
#
# ------------------------------------------
# ------------------------------------------
# DecisionTreeClassifier(class_weight='balanced', random_state=0):
# [[52616  4831]
#  [ 4558  1415]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.92      0.92     57447
#          1.0       0.23      0.24      0.23      5973
#
#     accuracy                           0.85     63420
#    macro avg       0.57      0.58      0.57     63420
# weighted avg       0.85      0.85      0.85     63420
#
# ------------------------------------------
# ------------------------------------------
# RandomForestClassifier(class_weight='balanced', random_state=0):
# [[56541   906]
#  [ 5390   583]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.98      0.95     57447
#          1.0       0.39      0.10      0.16      5973
#
#     accuracy                           0.90     63420
#    macro avg       0.65      0.54      0.55     63420
# weighted avg       0.86      0.90      0.87     63420
#
# ------------------------------------------
# ------------------------------------------
# AdaBoostClassifier(random_state=0):
# [[56706   741]
#  [ 5165   808]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95     57447
#          1.0       0.52      0.14      0.21      5973
#
#     accuracy                           0.91     63420
#    macro avg       0.72      0.56      0.58     63420
# weighted avg       0.88      0.91      0.88     63420
#
# ------------------------------------------
# ------------------------------------------
# GaussianNB():
# [[48489  8958]
#  [ 2752  3221]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.84      0.89     57447
#          1.0       0.26      0.54      0.35      5973
#
#     accuracy                           0.82     63420
#    macro avg       0.61      0.69      0.62     63420
# weighted avg       0.88      0.82      0.84     63420
#
# ------------------------------------------
# ------------------------------------------
# QuadraticDiscriminantAnalysis():
# [[49873  7574]
#  [ 3066  2907]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.87      0.90     57447
#          1.0       0.28      0.49      0.35      5973
#
#     accuracy                           0.83     63420
#    macro avg       0.61      0.68      0.63     63420
# weighted avg       0.88      0.83      0.85     63420
#
# ------------------------------------------
# ------------------------------------------
# GradientBoostingClassifier(random_state=0):
# [[56936   511]
#  [ 5319   654]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95     57447
#          1.0       0.56      0.11      0.18      5973
#
#     accuracy                           0.91     63420
#    macro avg       0.74      0.55      0.57     63420
# weighted avg       0.88      0.91      0.88     63420
#
# ------------------------------------------
# ------------------------------------------
# GradientBoostingClassifier(loss='exponential', random_state=0):
# [[57024   423]
#  [ 5417   556]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95     57447
#          1.0       0.57      0.09      0.16      5973
#
#     accuracy                           0.91     63420
#    macro avg       0.74      0.54      0.56     63420
# weighted avg       0.88      0.91      0.88     63420
#
# ------------------------------------------
# ------------------------------------------
